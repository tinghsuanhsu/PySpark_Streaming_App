# %%
import os
# set the Kafka version
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.3.0 pyspark-shell'


import sys
import time
import json
from pymongo import MongoClient
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

  

n_secs = 10
topic = 'climate'

conf = SparkConf().setAppName("KafkaStreamProcessor").setMaster("local[2]")
sc = SparkContext.getOrCreate()
if sc is None:
    sc = SparkContext(conf=conf)
sc.setLogLevel("WARN")
ssc = StreamingContext(sc, n_secs)
    


def sendDataToDB(messages): 
    
    client = MongoClient()
    db = client.fit5148_db
    week11 = db.new # send to this collection
    
    
    all_record = [] # to store the streaming records
    all_producer = {} # to store records from 3 producers
    all_location = {} # to store records from different locations
    
    # for each record in Dstream RDD partition, do the following
    for record in messages:
        data = json.loads(record[1]) # change data to json format 
        all_record.append(data) # add data to a list 
    
    # this part creates a dictionary that is in the form of {producer: [{record}]}
    # have 1 to 3 keys 
    # for each json item in the list, do the following 
    for m in all_record:
        if int(m['sender_id']) not in list(all_producer.keys()):
            all_producer[int(m['sender_id'])] = [m]
            print ('no')
        else:
            all_producer[int(m['sender_id'])].append(m) 
            print('yes')

            
    # this part joins the streams by geohash. use a dictionary to collect the results in the form of {geogash: [{record}]}
    # have 1 to 4 keys  
    # for each json item in the list, do the following 
    for m in all_record:
        if m['geohash'] not in list(all_location.keys()):
            all_location[m['geohash']] = [m]
        else: 
            all_location[m['geohash']].append(m)
     # when we only receive data from producer 1, send this climate data directly to MongoDB
    if len(set(list(all_producer.keys()))) == 1 and set(list(all_producer.keys())) == set([1]):
        
        for value in all_producer.values():
            
            content_climate = {'latitude':float(value[0]['latitude']), 
                               'longitude':float(value[0]['longitude']), 
                               'air_temperature_celcius':int(value[0]['air_temperature_celcius']), 
                               'relative_humidity':float(value[0]['relative_humidity']),
                               'windspeed_knots':float(value[0]['windspeed_knots']),
                               'max_wind_speed':float(value[0]['max_wind_speed']),
                               'precipitation':value[0]['precipitation'],
                               'datetime': value[0]['created_time']}

            week11.insert_one(content_climate)
   

    # when have records from more than 1 producers 
    elif len(set(all_producer.keys())) > 1:

        # loop through the locations dictionary to check scenearios:
        # 1. if we have only climate data (1 or 2 for the same location)--> insert into MongoDB
        # 2. if we have hotspot data and climate data --> embed hotspot in climate --> insert into MongoDB
        # 3. if we have hotspot data without climate data --> do not store
        # 4. if we have hotspot data with a shared location from TERRA and AQUA & also a matching climate record  
        #    --> average confidence and surface temperature celcius --> embed hotspot in climate --> insert into MongoDB
    
        for value in all_location.values():
            
            # scenario 1: location only has data from producer 1 
            if len(value) == 1 and int(value[0]['sender_id']) == 1:
                
                        content_climate = {'latitude':float(value[0]['latitude']), 
                               'longitude':float(value[0]['longitude']), 
                               'air_temperature_celcius':int(value[0]['air_temperature_celcius']), 
                               'relative_humidity':float(value[0]['relative_humidity']),
                               'windspeed_knots':float(value[0]['windspeed_knots']),
                               'max_wind_speed':float(value[0]['max_wind_speed']),
                               'precipitation':value[0]['precipitation'],
                               'datetime': value[0]['created_time']}
                        
                        week11.insert_one(content_climate)
    
          


            # scenario 2: same location has data from 
            # producer 1,1 || producer 1,2 || producer 1,3 || producer 2,3 (we do not store)
            elif len(value) == 2:

                # records could be in the order of 3,1 or 2,1
                # therefore loop through all the records then determine if we need to embed hotspot into climate
                
                has_climate = False # track if we have climate data 
                has_hotspot = False # track if we have hotspot data 
                has_another_climate = False # track if we have another climate data 


                # for each record in this location, do the following
                for i in range(len(value)):
                    
                    temp = value[i] # a dictionary 
                    
                    # the case which we have only seen one climate data, create a climate content
                    if int(temp['sender_id']) == 1 and has_climate == False:
                        content_climate = {'latitude':float(temp['latitude']), 
                               'longitude':float(temp['longitude']), 
                               'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                               'relative_humidity':float(temp['relative_humidity']),
                               'windspeed_knots':float(temp['windspeed_knots']),
                               'max_wind_speed':float(temp['max_wind_speed']),
                               'precipitation':temp['precipitation'],
                               'datetime': temp['created_time'],
                               'hotspot':[]}


                        has_climate = True # flag that this location has a climate data 

                    # the case which we have two climate data, create a second climate content
                    elif int(temp['sender_id']) == 1 and has_climate == True:

                        content_climate_2 = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time']}

                        has_another_climate = True

                    # create a hotspot content
                    else:

                        content_hotspot = {'latitude':float(temp['latitude']), 
                                                'longitude':float(temp['longitude']), 
                                                'confidence':int(temp['confidence']), 
                                                'time':temp['created_time'].split(' ')[1],
                                                'surface_temperature_celcius':float(temp['surface_temperature_celcius'])
                                               }



                        has_hotspot = True # flag that this location has a hotspot data 


                # perform embedding and insertion into MongoDB when we have both climate data & hotspot data 
                if has_hotspot and has_climate: 
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate
                    
                    try:
                        week11.insert_one(content_climate)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))
                
                # when we have 2 climate records 
                elif has_another_climate == True:
                    
                    content_climate.pop('hotspot') # do not need the extra hotspot attribute 
               
                    try:
                        week11.insert_one(content_climate)
                        week11.insert_one(content_climate_2)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))



         

            # when we have data from more than 1 producer
            # could have 1,1,2 || 1,1,3 || 1,2,3 || 1,1,2,3 
            # last two cases need to average confidence and air_temperature_celcius for both hotspots
            if len(value) > 2: 
                
                has_climate = False
                has_hotspot = False
                has_another_climate = False
        

                # for each record in this location, do the following
                for i in range(len(value)):
                    
                    temp = value[i] # a dictionary 

                    # the case which we have only seen one climate data, create a climate content
                    if int(temp['sender_id']) == 1 and has_climate == False:

                        content_climate = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time'],
                                   'hotspot':[]}


                        has_climate = True

                    # the case which we have two climate data, create a second climate content
                    elif int(temp['sender_id']) == 1 and has_climate == True:

                        content_climate_2 = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time'],
                                   'hotspot':[]}

                        has_another_climate = True

                    
                    # the case which we have hotspot data, create hotspot content for potential embedding
                    else:


                        # when there's hotspot exists for the same location from a different producer 
                        if has_hotspot: 

                            content_hotspot['confidence'] = (content_hotspot['confidence'] + float(temp['confidence'])) / 2
                            content_hotspot['surface_temperature_celcius'] = (content_hotspot['surface_temperature_celcius'] \
                                                                              + float(temp['surface_temperature_celcius'])) / 2


                        # when there's no hotspot exists from either 2 or 3 
                        else: 
                            content_hotspot = {'latitude':float(temp['latitude']), 
                                                'longitude':float(temp['longitude']), 
                                                'confidence':int(temp['confidence']),
                                                'time':temp['created_time'].split(' ')[1],
                                                'surface_temperature_celcius':float(temp['surface_temperature_celcius'])
                                               }



                        has_hotspot = True 


                # insert two records when we have 1,1,2 or 1,1,3 or 1,1,2,3
                if has_another_climate == True:
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate record 1
                    content_climate_2['hotspot'].append(content_hotspot) # embed hotspot into climate record 2
                    try:
                        week11.insert_one(content_climate)
                        week11.insert_one(content_climate_2)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))

                # insert one record when we have 1,2,3
                else:
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate
                    try:
                        week11.insert_one(content_climate)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))


                
        client.close()

        
        
        
        
        
kafkaStream = KafkaUtils.createDirectStream(ssc,[topic], {
                        'bootstrap.servers':'127.0.0.1:9092', 
                        'group.id':'week11-group', 
                        'fet`ch.message.max.bytes':'15728640',
                        'auto.offset.reset':'largest'})
                        # Group ID is completely arbitrary
kafkaStream.pprint()
lines = kafkaStream.foreachRDD(lambda rdd: rdd.foreachPartition(sendDataToDB))


ssc.start()
time.sleep(600) # Run stream for 10 minutes just in case no detection of producer
# ssc.awaitTermination()
ssc.stop(stopSparkContext=True,stopGraceFully=True)
# Out:
# -------------------------------------------
# Time: 2019-05-24 15:58:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-24 15:59:00
# -------------------------------------------
# (None, '{"geohash": "r1me7", "longitude": "142.8935", "sender_id": "2", "latitude": "-37.3847", "surface_temperature_celcius": "88", "created_time": "2019-05-24 15:58:54", "confidence": "100"}')
#
# -------------------------------------------
# Time: 2019-05-24 15:59:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-24 15:59:20
# -------------------------------------------
# (None, '{"latitude": "-36.6942", "longitude": "143.8021", "geohash": "r1qr2", "created_time": "2019-05-24 15:59:12", "confidence": "93", "sender_id": "3", "surface_temperature_celcius": "72"}')
# (None, '{"geohash": "r1jr8", "longitude": "142.3959", "sender_id": "2", "latitude": "-38.0254", "surface_temperature_celcius": "99", "created_time": "2019-05-24 15:59:15", "confidence": "100"}')
#
# -------------------------------------------
# Time: 2019-05-24 15:59:30
# -------------------------------------------
# (None, '{"geohash": "r1kwb", "longitude": "141.3318", "sender_id": "2", "latitude": "-36.7469", "surface_temperature_celcius": "61", "created_time": "2019-05-24 15:59:26", "confidence": "86"}')
# (None, '{"latitude": "-36.7593", "longitude": "142.895", "geohash": "r1mwg", "created_time": "2019-05-24 15:59:28", "confidence": "92", "sender_id": "3", "surface_temperature_celcius": "69"}')
#
# -------------------------------------------
# Time: 2019-05-24 15:59:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-24 15:59:50
# -------------------------------------------
# (None, '{"latitude": "-36.3972", "longitude": "141.6041", "geohash": "r1s8y", "created_time": "2019-05-24 15:59:47", "confidence": "100", "sender_id": "3", "surface_temperature_celcius": "90"}')
# (None, '{"geohash": "r1s2b", "longitude": "140.9806", "sender_id": "2", "latitude": "-36.4057", "surface_temperature_celcius": "119", "created_time": "2019-05-24 15:59:48", "confidence": "100"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:00:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-24 16:00:10
# -------------------------------------------
# (None, '{"latitude": "-36.884", "longitude": "145.8938", "geohash": "r1rwp", "created_time": "2019-05-24 16:00:07", "confidence": "66", "sender_id": "3", "surface_temperature_celcius": "43"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:00:20
# -------------------------------------------
# (None, '{"latitude": "-36.6492", "longitude": "142.3976", "geohash": "r1mr8", "created_time": "2019-05-24 16:00:18", "confidence": "66", "sender_id": "3", "surface_temperature_celcius": "60"}')
# (None, '{"geohash": "r1mnt", "longitude": "142.2675", "sender_id": "2", "latitude": "-36.82", "surface_temperature_celcius": "53", "created_time": "2019-05-24 16:00:18", "confidence": "80"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:00:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2019-05-24 16:00:40
# -------------------------------------------
# (None, '{"latitude": "-36.984", "longitude": "148.25", "geohash": "r33mt", "created_time": "2019-05-24 16:00:33", "confidence": "50", "sender_id": "3", "surface_temperature_celcius": "35"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:00:50
# -------------------------------------------
# (None, '{"geohash": "r336f", "longitude": "148.126", "sender_id": "2", "latitude": "-37.45", "surface_temperature_celcius": "69", "created_time": "2019-05-24 16:00:46", "confidence": "64"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:00
# -------------------------------------------
# (None, '{"latitude": "-36.4339", "longitude": "141.5458", "geohash": "r1s8s", "created_time": "2019-05-24 16:00:58", "confidence": "87", "sender_id": "3", "surface_temperature_celcius": "62"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:01:05", "longitude": "141.0437", "sender_id": "1", "latitude": "-37.0684", "max_wind_speed": "13", "windspeed_knots": "6", "relative_humidity": "51.1", "precipitation": "0.12G", "geohash": "r1km1", "air_temperature_celcius": "13"}')
# (None, '{"geohash": "r1kx7", "longitude": "141.4943", "sender_id": "2", "latitude": "-36.6516", "surface_temperature_celcius": "48", "created_time": "2019-05-24 16:01:07", "confidence": "74"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:01:10", "longitude": "141.089", "sender_id": "1", "latitude": "-35.961", "max_wind_speed": "11.1", "windspeed_knots": "4.3", "relative_humidity": "34.9", "precipitation": "0.00A", "geohash": "r1s76", "air_temperature_celcius": "5"}')
# (None, '{"created_time": "2019-05-24 16:01:15", "longitude": "141.078", "sender_id": "1", "latitude": "-35.963", "max_wind_speed": "14", "windspeed_knots": "5.8", "relative_humidity": "33.1", "precipitation": "0.00I", "geohash": "r1s76", "air_temperature_celcius": "5"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:30
# -------------------------------------------
# (None, '{"latitude": "-35.2381", "longitude": "142.994", "geohash": "r1txt", "created_time": "2019-05-24 16:01:20", "confidence": "98", "sender_id": "3", "surface_temperature_celcius": "83"}')
# (None, '{"created_time": "2019-05-24 16:01:20", "longitude": "149.308", "sender_id": "1", "latitude": "-37.605", "max_wind_speed": "14", "windspeed_knots": "10.7", "relative_humidity": "48.5", "precipitation": "0.71G", "geohash": "r364j", "air_temperature_celcius": "13"}')
# (None, '{"created_time": "2019-05-24 16:01:25", "longitude": "146.272", "sender_id": "1", "latitude": "-38.912", "max_wind_speed": "15", "windspeed_knots": "10.8", "relative_humidity": "53.3", "precipitation": "0.00G", "geohash": "r3048", "air_temperature_celcius": "18"}')
# (None, '{"geohash": "r1qkf", "longitude": "143.906", "sender_id": "2", "latitude": "-37.0908", "surface_temperature_celcius": "46", "created_time": "2019-05-24 16:01:29", "confidence": "71"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:40
# -------------------------------------------
# (None, '{"latitude": "-37.336", "longitude": "148.073", "geohash": "r3379", "created_time": "2019-05-24 16:01:30", "confidence": "82", "sender_id": "3", "surface_temperature_celcius": "38"}')
# (None, '{"created_time": "2019-05-24 16:01:30", "longitude": "142.3787", "sender_id": "1", "latitude": "-35.6374", "max_wind_speed": "18.1", "windspeed_knots": "13.1", "relative_humidity": "41.6", "precipitation": "0.00I", "geohash": "r1tjr", "air_temperature_celcius": "14"}')
# (None, '{"created_time": "2019-05-24 16:01:35", "longitude": "144.176", "sender_id": "1", "latitude": "-36.765", "max_wind_speed": "9.9", "windspeed_knots": "5.9", "relative_humidity": "54.9", "precipitation": "0.00I", "geohash": "r1qwb", "air_temperature_celcius": "16"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:01:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:01:40", "longitude": "143.8907", "sender_id": "1", "latitude": "-36.0459", "max_wind_speed": "13", "windspeed_knots": "7.8", "relative_humidity": "58.7", "precipitation": "0.00I", "geohash": "r1w6f", "air_temperature_celcius": "21"}')
# (None, '{"created_time": "2019-05-24 16:01:45", "longitude": "148.115", "sender_id": "1", "latitude": "-37.452", "max_wind_speed": "14", "windspeed_knots": "7.3", "relative_humidity": "43.8", "precipitation": "0.08G", "geohash": "r336f", "air_temperature_celcius": "8"}')
# (None, '{"latitude": "-36.3455", "longitude": "141.5655", "geohash": "r1s9j", "created_time": "2019-05-24 16:01:48", "confidence": "75", "sender_id": "3", "surface_temperature_celcius": "49"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:02:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:01:50", "longitude": "146.145", "sender_id": "1", "latitude": "-36.284", "max_wind_speed": "18.1", "windspeed_knots": "11.2", "relative_humidity": "54.1", "precipitation": "0.31G", "geohash": "r1xct", "air_temperature_celcius": "19"}')
# (None, '{"created_time": "2019-05-24 16:01:55", "longitude": "146.151", "sender_id": "1", "latitude": "-36.285", "max_wind_speed": "8.9", "windspeed_knots": "5.8", "relative_humidity": "56.3", "precipitation": "0.00I", "geohash": "r1xct", "air_temperature_celcius": "19"}')
# (None, '{"geohash": "r1nqz", "longitude": "144.1275", "sender_id": "2", "latitude": "-38.1536", "surface_temperature_celcius": "50", "created_time": "2019-05-24 16:01:58", "confidence": "77"}')
# -------------------------------------------
# Time: 2019-05-24 16:02:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:00", "longitude": "148.067", "sender_id": "1", "latitude": "-37.401", "max_wind_speed": "19", "windspeed_knots": "14", "relative_humidity": "42.5", "precipitation": "0.04G", "geohash": "r3371", "air_temperature_celcius": "13"}')
# (None, '{"created_time": "2019-05-24 16:02:05", "longitude": "148.042", "sender_id": "1", "latitude": "-37.376", "max_wind_speed": "8", "windspeed_knots": "5.5", "relative_humidity": "43.2", "precipitation": "0.00G", "geohash": "r3372", "air_temperature_celcius": "11"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:02:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:10", "longitude": "141.5355", "sender_id": "1", "latitude": "-37.013", "max_wind_speed": "12", "windspeed_knots": "7.3", "relative_humidity": "44.1", "precipitation": "0.39G", "geohash": "r1ktk", "air_temperature_celcius": "10"}')
# (None, '{"latitude": "-36.7145", "longitude": "143.471", "geohash": "r1qp0", "created_time": "2019-05-24 16:02:12", "confidence": "78", "sender_id": "3", "surface_temperature_celcius": "52"}')
# (None, '{"created_time": "2019-05-24 16:02:15", "longitude": "145.179", "sender_id": "1", "latitude": "-36.759", "max_wind_speed": "19", "windspeed_knots": "12.8", "relative_humidity": "55.6", "precipitation": "0.00I", "geohash": "r1rnz", "air_temperature_celcius": "18"}')
# (None, '{"geohash": "r1tc7", "longitude": "143.2349", "sender_id": "2", "latitude": "-36.301", "surface_temperature_celcius": "45", "created_time": "2019-05-24 16:02:16", "confidence": "70"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:02:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:20", "longitude": "143.7079", "sender_id": "1", "latitude": "-36.3774", "max_wind_speed": "14", "windspeed_knots": "8.1", "relative_humidity": "43.2", "precipitation": "0.20G", "geohash": "r1w1n", "air_temperature_celcius": "11"}')
# (None, '{"created_time": "2019-05-24 16:02:25", "longitude": "148.063", "sender_id": "1", "latitude": "-37.375", "max_wind_speed": "16.9", "windspeed_knots": "12", "relative_humidity": "43.5", "precipitation": "0.04G", "geohash": "r3373", "air_temperature_celcius": "10"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:02:40
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:30", "longitude": "148.11", "sender_id": "1", "latitude": "-37.456", "max_wind_speed": "7", "windspeed_knots": "4.1", "relative_humidity": "47.9", "precipitation": "0.00I", "geohash": "r336f", "air_temperature_celcius": "10"}')
# (None, '{"geohash": "r336g", "longitude": "148.143", "sender_id": "2", "latitude": "-37.457", "surface_temperature_celcius": "41", "created_time": "2019-05-24 16:02:31", "confidence": "90"}')
# (None, '{"created_time": "2019-05-24 16:02:35", "longitude": "141.4943", "sender_id": "1", "latitude": "-36.6516", "max_wind_speed": "15", "windspeed_knots": "8.5", "relative_humidity": "45.3", "precipitation": "0.00G", "geohash": "r1kx7", "air_temperature_celcius": "11"}')
# (None, '{"latitude": "-37.5788", "longitude": "148.592", "geohash": "r33dj", "created_time": "2019-05-24 16:02:36", "confidence": "90", "sender_id": "3", "surface_temperature_celcius": "67"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:02:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:40", "longitude": "143.183", "sender_id": "1", "latitude": "-38.141", "max_wind_speed": "14", "windspeed_knots": "5.7", "relative_humidity": "54.1", "precipitation": "0.00I", "geohash": "r1jz4", "air_temperature_celcius": "23"}')
# (None, '{"created_time": "2019-05-24 16:02:45", "longitude": "143.451", "sender_id": "1", "latitude": "-37.614", "max_wind_speed": "12", "windspeed_knots": "6.4", "relative_humidity": "60.2", "precipitation": "0.00I", "geohash": "r1q40", "air_temperature_celcius": "19"}')
# (None, '{"geohash": "r1npm", "longitude": "143.6616", "sender_id": "2", "latitude": "-38.0643", "surface_temperature_celcius": "43", "created_time": "2019-05-24 16:02:47", "confidence": "57"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:03:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:02:50", "longitude": "142.538", "sender_id": "1", "latitude": "-36.701", "max_wind_speed": "11.1", "windspeed_knots": "5.5", "relative_humidity": "61.5", "precipitation": "0.28G", "geohash": "r1mr5", "air_temperature_celcius": "18"}')
# (None, '{"created_time": "2019-05-24 16:02:55", "longitude": "146.157", "sender_id": "1", "latitude": "-36.282", "max_wind_speed": "16.9", "windspeed_knots": "11.9", "relative_humidity": "50.4", "precipitation": "0.00G", "geohash": "r1xct", "air_temperature_celcius": "17"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:03:10
# -------------------------------------------
# (None, '{"geohash": "r1mfy", "longitude": "143.365", "sender_id": "2", "latitude": "-37.475", "surface_temperature_celcius": "77", "created_time": "2019-05-24 16:03:00", "confidence": "96"}')
# (None, '{"latitude": "-36.3256", "longitude": "141.095", "geohash": "r1s36", "created_time": "2019-05-24 16:03:00", "confidence": "72", "sender_id": "3", "surface_temperature_celcius": "47"}')
# (None, '{"created_time": "2019-05-24 16:03:00", "longitude": "143.281", "sender_id": "1", "latitude": "-36.94", "max_wind_speed": "11.1", "windspeed_knots": "4.1", "relative_humidity": "52.8", "precipitation": "0.00I", "geohash": "r1mvu", "air_temperature_celcius": "21"}')
# (None, '{"created_time": "2019-05-24 16:03:05", "longitude": "141.146", "sender_id": "1", "latitude": "-37.227", "max_wind_speed": "8.9", "windspeed_knots": "5.5", "relative_humidity": "44.9", "precipitation": "0.00G", "geohash": "r1kk5", "air_temperature_celcius": "10"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:03:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:03:10", "longitude": "147.207", "sender_id": "1", "latitude": "-37.886", "max_wind_speed": "12", "windspeed_knots": "5.9", "relative_humidity": "54.3", "precipitation": "0.00I", "geohash": "r328m", "air_temperature_celcius": "19"}')
# (None, '{"created_time": "2019-05-24 16:03:15", "longitude": "141.278", "sender_id": "1", "latitude": "-37.247", "max_wind_speed": "14", "windspeed_knots": "7.1", "relative_humidity": "47.4", "precipitation": "0.00I", "geohash": "r1kkn", "air_temperature_celcius": "14"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:03:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:03:20", "longitude": "144.972", "sender_id": "1", "latitude": "-36.952", "max_wind_speed": "9.9", "windspeed_knots": "5.4", "relative_humidity": "57.3", "precipitation": "0.00I", "geohash": "r1rjf", "air_temperature_celcius": "21"}')
# (None, '{"geohash": "r1w3p", "longitude": "144.0984", "sender_id": "2", "latitude": "-36.3463", "surface_temperature_celcius": "49", "created_time": "2019-05-24 16:03:22", "confidence": "76"}')
# (None, '{"created_time": "2019-05-24 16:03:25", "longitude": "148.105", "sender_id": "1", "latitude": "-37.415", "max_wind_speed": "15", "windspeed_knots": "7.7", "relative_humidity": "47", "precipitation": "0.08G", "geohash": "r3374", "air_temperature_celcius": "12"}')
# (None, '{"latitude": "-36.9077", "longitude": "142.6861", "geohash": "r1mqn", "created_time": "2019-05-24 16:03:26", "confidence": "88", "sender_id": "3", "surface_temperature_celcius": "64"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:03:40
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:03:30", "longitude": "149.302", "sender_id": "1", "latitude": "-37.605", "max_wind_speed": "9.9", "windspeed_knots": "5.7", "relative_humidity": "54.4", "precipitation": "0.00I", "geohash": "r364j", "air_temperature_celcius": "18"}')
# (None, '{"geohash": "r1m2b", "longitude": "142.4083", "sender_id": "2", "latitude": "-37.8297", "surface_temperature_celcius": "48", "created_time": "2019-05-24 16:03:34", "confidence": "72"}')
# (None, '{"created_time": "2019-05-24 16:03:35", "longitude": "144.342", "sender_id": "1", "latitude": "-37.946", "max_wind_speed": "16.9", "windspeed_knots": "7.4", "relative_humidity": "54.9", "precipitation": "0.00I", "geohash": "r1q8h", "air_temperature_celcius": "21"}')
# -------------------------------------------
# Time: 2019-05-24 16:03:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:03:40", "longitude": "143.4996", "sender_id": "1", "latitude": "-36.9364", "max_wind_speed": "18.1", "windspeed_knots": "12.3", "relative_humidity": "41.7", "precipitation": "0.00G", "geohash": "r1qjc", "air_temperature_celcius": "14"}')
# (None, '{"created_time": "2019-05-24 16:03:45", "longitude": "143.352", "sender_id": "1", "latitude": "-37.477", "max_wind_speed": "13", "windspeed_knots": "6", "relative_humidity": "50.6", "precipitation": "0.00G", "geohash": "r1mfy", "air_temperature_celcius": "18"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:03:50", "longitude": "148.104", "sender_id": "1", "latitude": "-37.437", "max_wind_speed": "21", "windspeed_knots": "16.7", "relative_humidity": "40.7", "precipitation": "0.12G", "geohash": "r3374", "air_temperature_celcius": "12"}')
# (None, '{"latitude": "-37.0643", "longitude": "141.8567", "geohash": "r1kvh", "created_time": "2019-05-24 16:03:51", "confidence": "50", "sender_id": "3", "surface_temperature_celcius": "40"}')
# (None, '{"geohash": "r32wg", "longitude": "147.1243", "sender_id": "2", "latitude": "-36.7408", "surface_temperature_celcius": "49", "created_time": "2019-05-24 16:03:53", "confidence": "100"}')
# (None, '{"created_time": "2019-05-24 16:03:55", "longitude": "141.0692", "sender_id": "1", "latitude": "-37.0745", "max_wind_speed": "9.9", "windspeed_knots": "6.9", "relative_humidity": "40.4", "precipitation": "0.02G", "geohash": "r1km4", "air_temperature_celcius": "9"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:04:00", "longitude": "148.091", "sender_id": "1", "latitude": "-37.471", "max_wind_speed": "15", "windspeed_knots": "6.7", "relative_humidity": "40.8", "precipitation": "0.01G", "geohash": "r336c", "air_temperature_celcius": "9"}')
# (None, '{"latitude": "-36.941", "longitude": "143.268", "geohash": "r1mvu", "created_time": "2019-05-24 16:04:02", "confidence": "80", "sender_id": "3", "surface_temperature_celcius": "37"}')
# (None, '{"created_time": "2019-05-24 16:04:05", "longitude": "141.153", "sender_id": "1", "latitude": "-37.242", "max_wind_speed": "19", "windspeed_knots": "12.1", "relative_humidity": "42.8", "precipitation": "0.04G", "geohash": "r1kkh", "air_temperature_celcius": "12"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:04:10", "longitude": "142.2098", "sender_id": "1", "latitude": "-36.8835", "max_wind_speed": "15", "windspeed_knots": "7.9", "relative_humidity": "41.6", "precipitation": "0.01G", "geohash": "r1mnh", "air_temperature_celcius": "11"}')
# (None, '{"created_time": "2019-05-24 16:04:15", "longitude": "146.288", "sender_id": "1", "latitude": "-37.637", "max_wind_speed": "23.9", "windspeed_knots": "14.1", "relative_humidity": "61.9", "precipitation": "0.00I", "geohash": "r321b", "air_temperature_celcius": "31"}')
# (None, '{"geohash": "r328m", "longitude": "147.207", "sender_id": "2", "latitude": "-37.886", "surface_temperature_celcius": "28", "created_time": "2019-05-24 16:04:18", "confidence": "50"}')
# (None, '{"latitude": "-37.9257", "longitude": "143.4891", "geohash": "r1q01", "created_time": "2019-05-24 16:04:19", "confidence": "63", "sender_id": "3", "surface_temperature_celcius": "54"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:04:21", "longitude": "146.944", "sender_id": "1", "latitude": "-38.495", "max_wind_speed": "8", "windspeed_knots": "3.9", "relative_humidity": "44.6", "precipitation": "0.39G", "geohash": "r30mp", "air_temperature_celcius": "8"}')
# (None, '{"created_time": "2019-05-24 16:04:26", "longitude": "141.076", "sender_id": "1", "latitude": "-35.954", "max_wind_speed": "15", "windspeed_knots": "9.4", "relative_humidity": "42.1", "precipitation": "0.13B", "geohash": "r1s76", "air_temperature_celcius": "10"}')
# (None, '{"geohash": "r1qr5", "longitude": "143.9213", "sender_id": "2", "latitude": "-36.7223", "surface_temperature_celcius": "47", "created_time": "2019-05-24 16:04:28", "confidence": "73"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:40
# -------------------------------------------
# (None, '{"latitude": "-37.4479", "longitude": "142.9012", "geohash": "r1mdg", "created_time": "2019-05-24 16:04:30", "confidence": "80", "sender_id": "3", "surface_temperature_celcius": "53"}')
# (None, '{"created_time": "2019-05-24 16:04:31", "longitude": "143.0246", "sender_id": "1", "latitude": "-37.5865", "max_wind_speed": "14", "windspeed_knots": "7.3", "relative_humidity": "53.5", "precipitation": "0.00I", "geohash": "r1mdn", "air_temperature_celcius": "17"}')
# (None, '{"created_time": "2019-05-24 16:04:36", "longitude": "149.232", "sender_id": "1", "latitude": "-37.63", "max_wind_speed": "15", "windspeed_knots": "7.4", "relative_humidity": "57", "precipitation": "0.00I", "geohash": "r361g", "air_temperature_celcius": "18"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:04:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:04:41", "longitude": "144.168", "sender_id": "1", "latitude": "-36.748", "max_wind_speed": "22.9", "windspeed_knots": "10.8", "relative_humidity": "48.2", "precipitation": "0.59G", "geohash": "r1qwb", "air_temperature_celcius": "11"}')
# (None, '{"geohash": "r1q03", "longitude": "143.4866", "sender_id": "2", "latitude": "-37.9164", "surface_temperature_celcius": "54", "created_time": "2019-05-24 16:04:41", "confidence": "58"}')
# (None, '{"created_time": "2019-05-24 16:04:46", "longitude": "141.712", "sender_id": "1", "latitude": "-34.289", "max_wind_speed": "19", "windspeed_knots": "12.8", "relative_humidity": "54.1", "precipitation": "0.00I", "geohash": "r1uub", "air_temperature_celcius": "32"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:05:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:04:51", "longitude": "144.6926", "sender_id": "1", "latitude": "-37.7052", "max_wind_speed": "14", "windspeed_knots": "7.7", "relative_humidity": "52.7", "precipitation": "0.00G", "geohash": "r1qck", "air_temperature_celcius": "17"}')
# (None, '{"created_time": "2019-05-24 16:04:56", "longitude": "143.918", "sender_id": "1", "latitude": "-37.954", "max_wind_speed": "15.9", "windspeed_knots": "8.6", "relative_humidity": "59.7", "precipitation": "0.01G", "geohash": "r1q24", "air_temperature_celcius": "20"}')
# (None, '{"latitude": "-37.4574", "longitude": "142.9354", "geohash": "r1mdu", "created_time": "2019-05-24 16:04:58", "confidence": "59", "sender_id": "3", "surface_temperature_celcius": "40"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:05:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:01", "longitude": "145.2096", "sender_id": "1", "latitude": "-36.1462", "max_wind_speed": "14", "windspeed_knots": "9.7", "relative_humidity": "43.6", "precipitation": "0.20G", "geohash": "r1x62", "air_temperature_celcius": "10"}')
# (None, '{"created_time": "2019-05-24 16:05:06", "longitude": "143.841", "sender_id": "1", "latitude": "-38.167", "max_wind_speed": "11.1", "windspeed_knots": "5.3", "relative_humidity": "58.1", "precipitation": "0.00G", "geohash": "r1nqc", "air_temperature_celcius": "21"}')
# (None, '{"geohash": "r1qkb", "longitude": "143.8311", "sender_id": "2", "latitude": "-37.0927", "surface_temperature_celcius": "53", "created_time": "2019-05-24 16:05:07", "confidence": "80"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:05:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:11", "longitude": "148.117", "sender_id": "1", "latitude": "-36.851", "max_wind_speed": "6", "windspeed_knots": "2.5", "relative_humidity": "45.3", "precipitation": "0.00G", "geohash": "r33q6", "air_temperature_celcius": "9"}')
# (None, '{"created_time": "2019-05-24 16:05:16", "longitude": "148.103", "sender_id": "1", "latitude": "-37.469", "max_wind_speed": "8.9", "windspeed_knots": "4.6", "relative_humidity": "47.1", "precipitation": "0.00G", "geohash": "r336f", "air_temperature_celcius": "10"}')
# (None, '{"geohash": "r30tc", "longitude": "147.0408", "sender_id": "2", "latitude": "-38.3525", "surface_temperature_celcius": "56", "created_time": "2019-05-24 16:05:18", "confidence": "72"}')
# -------------------------------------------
# Time: 2019-05-24 16:05:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:21", "longitude": "146.7777", "sender_id": "1", "latitude": "-37.1815", "max_wind_speed": "16.9", "windspeed_knots": "10.8", "relative_humidity": "50.4", "precipitation": "0.00I", "geohash": "r32kk", "air_temperature_celcius": "17"}')
# (None, '{"latitude": "-36.4489", "longitude": "144.1445", "geohash": "r1w88", "created_time": "2019-05-24 16:05:22", "confidence": "69", "sender_id": "3", "surface_temperature_celcius": "45"}')
# (None, '{"created_time": "2019-05-24 16:05:26", "longitude": "143.28", "sender_id": "1", "latitude": "-36.939", "max_wind_speed": "14", "windspeed_knots": "8.5", "relative_humidity": "67.4", "precipitation": "0.63G", "geohash": "r1mvu", "air_temperature_celcius": "20"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:05:40
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:31", "longitude": "143.0551", "sender_id": "1", "latitude": "-37.5268", "max_wind_speed": "20", "windspeed_knots": "14.4", "relative_humidity": "35", "precipitation": "0.00G", "geohash": "r1mdx", "air_temperature_celcius": "8"}')
# (None, '{"latitude": "-36.4409", "longitude": "141.6948", "geohash": "r1sb8", "created_time": "2019-05-24 16:05:34", "confidence": "100", "sender_id": "3", "surface_temperature_celcius": "92"}')
# (None, '{"created_time": "2019-05-24 16:05:36", "longitude": "143.605", "sender_id": "1", "latitude": "-37.69", "max_wind_speed": "15.9", "windspeed_knots": "9.2", "relative_humidity": "45.7", "precipitation": "0.00I", "geohash": "r1q1e", "air_temperature_celcius": "14"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:05:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:41", "longitude": "149.279", "sender_id": "1", "latitude": "-37.61", "max_wind_speed": "22", "windspeed_knots": "10.9", "relative_humidity": "57.4", "precipitation": "0.00I", "geohash": "r364h", "air_temperature_celcius": "20"}')
# (None, '{"geohash": "r32fz", "longitude": "147.6331", "sender_id": "2", "latitude": "-37.4471", "surface_temperature_celcius": "65", "created_time": "2019-05-24 16:05:42", "confidence": "89"}')
# (None, '{"created_time": "2019-05-24 16:05:46", "longitude": "141.828", "sender_id": "1", "latitude": "-37.1104", "max_wind_speed": "15", "windspeed_knots": "10.5", "relative_humidity": "46.2", "precipitation": "0.28G", "geohash": "r1kug", "air_temperature_celcius": "11"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:05:51", "longitude": "143.767", "sender_id": "1", "latitude": "-36.1", "max_wind_speed": "15.9", "windspeed_knots": "7.2", "relative_humidity": "53.5", "precipitation": "0.31G", "geohash": "r1w4x", "air_temperature_celcius": "20"}')
# (None, '{"created_time": "2019-05-24 16:05:56", "longitude": "142.6138", "sender_id": "1", "latitude": "-36.8264", "max_wind_speed": "25.1", "windspeed_knots": "14.7", "relative_humidity": "48.2", "precipitation": "0.43G", "geohash": "r1mqm", "air_temperature_celcius": "15"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:06:01", "longitude": "149.311", "sender_id": "1", "latitude": "-37.389", "max_wind_speed": "14", "windspeed_knots": "6.6", "relative_humidity": "53", "precipitation": "0.00I", "geohash": "r365m", "air_temperature_celcius": "18"}')
# (None, '{"latitude": "-36.536", "longitude": "144.024", "geohash": "r1w2j", "created_time": "2019-05-24 16:06:03", "confidence": "77", "sender_id": "3", "surface_temperature_celcius": "50"}')
# (None, '{"geohash": "r1jxm", "longitude": "142.965", "sender_id": "2", "latitude": "-38.0674", "surface_temperature_celcius": "68", "created_time": "2019-05-24 16:06:05", "confidence": "91"}')
# (None, '{"created_time": "2019-05-24 16:06:06", "longitude": "149.297", "sender_id": "1", "latitude": "-37.6", "max_wind_speed": "19", "windspeed_knots": "10.9", "relative_humidity": "53.4", "precipitation": "0.00I", "geohash": "r364j", "air_temperature_celcius": "22"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:06:11", "longitude": "143.74", "sender_id": "1", "latitude": "-36.098", "max_wind_speed": "7", "windspeed_knots": "4.2", "relative_humidity": "59.3", "precipitation": "0.01G", "geohash": "r1w4w", "air_temperature_celcius": "17"}')
# (None, '{"created_time": "2019-05-24 16:06:16", "longitude": "142.5959", "sender_id": "1", "latitude": "-36.5794", "max_wind_speed": "15", "windspeed_knots": "7.9", "relative_humidity": "51.8", "precipitation": "0.00I", "geohash": "r1mru", "air_temperature_celcius": "24"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:06:21", "longitude": "142.941", "sender_id": "1", "latitude": "-37.213", "max_wind_speed": "15.9", "windspeed_knots": "8", "relative_humidity": "61.9", "precipitation": "0.00I", "geohash": "r1msk", "air_temperature_celcius": "23"}')
# (None, '{"created_time": "2019-05-24 16:06:26", "longitude": "143.803", "sender_id": "1", "latitude": "-38.16", "max_wind_speed": "15", "windspeed_knots": "7.1", "relative_humidity": "62.2", "precipitation": "0.00I", "geohash": "r1nqb", "air_temperature_celcius": "20"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:40
# -------------------------------------------
# (None, '{"geohash": "r1qwb", "longitude": "144.168", "sender_id": "2", "latitude": "-36.748", "surface_temperature_celcius": "44", "created_time": "2019-05-24 16:06:30", "confidence": "62"}')
# (None, '{"created_time": "2019-05-24 16:06:31", "longitude": "143.1062", "sender_id": "1", "latitude": "-37.8147", "max_wind_speed": "20", "windspeed_knots": "9.5", "relative_humidity": "46.4", "precipitation": "0.00I", "geohash": "r1mbb", "air_temperature_celcius": "17"}')
# (None, '{"latitude": "-37.9509", "longitude": "143.9599", "geohash": "r1q25", "created_time": "2019-05-24 16:06:31", "confidence": "95", "sender_id": "3", "surface_temperature_celcius": "76"}')
# (None, '{"created_time": "2019-05-24 16:06:36", "longitude": "142.479", "sender_id": "1", "latitude": "-37.587", "max_wind_speed": "18.1", "windspeed_knots": "11.9", "relative_humidity": "45.1", "precipitation": "0.16G", "geohash": "r1m64", "air_temperature_celcius": "12"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:06:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:06:41", "longitude": "148.086", "sender_id": "1", "latitude": "-37.396", "max_wind_speed": "28", "windspeed_knots": "15", "relative_humidity": "41.6", "precipitation": "0.00I", "geohash": "r3373", "air_temperature_celcius": "15"}')
# (None, '{"created_time": "2019-05-24 16:06:46", "longitude": "143.268", "sender_id": "1", "latitude": "-36.941", "max_wind_speed": "15.9", "windspeed_knots": "7.1", "relative_humidity": "63.8", "precipitation": "0.08G", "geohash": "r1mvu", "air_temperature_celcius": "23"}')
# (None, '{"geohash": "r1utp", "longitude": "141.6412", "sender_id": "2", "latitude": "-34.2614", "surface_temperature_celcius": "43", "created_time": "2019-05-24 16:06:46", "confidence": "57"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:07:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:06:51", "longitude": "144.233", "sender_id": "1", "latitude": "-36.0856", "max_wind_speed": "14", "windspeed_knots": "5.9", "relative_humidity": "43.2", "precipitation": "0.00I", "geohash": "r1wdd", "air_temperature_celcius": "11"}')
# (None, '{"created_time": "2019-05-24 16:06:56", "longitude": "148.117", "sender_id": "1", "latitude": "-37.478", "max_wind_speed": "16.9", "windspeed_knots": "11.2", "relative_humidity": "43.9", "precipitation": "0.12G", "geohash": "r336f", "air_temperature_celcius": "11"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:07:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:01", "longitude": "141.27", "sender_id": "1", "latitude": "-37.247", "max_wind_speed": "8", "windspeed_knots": "4.7", "relative_humidity": "43.1", "precipitation": "0.00G", "geohash": "r1kkn", "air_temperature_celcius": "10"}')
# (None, '{"latitude": "-37.8339", "longitude": "147.2118", "geohash": "r328v", "created_time": "2019-05-24 16:07:01", "confidence": "100", "sender_id": "3", "surface_temperature_celcius": "113"}')
# (None, '{"created_time": "2019-05-24 16:07:06", "longitude": "149.233", "sender_id": "1", "latitude": "-37.644", "max_wind_speed": "12", "windspeed_knots": "6.9", "relative_humidity": "58", "precipitation": "0.00I", "geohash": "r361g", "air_temperature_celcius": "22"}')
# (None, '{"geohash": "r1s9h", "longitude": "141.5238", "sender_id": "2", "latitude": "-36.3493", "surface_temperature_celcius": "45", "created_time": "2019-05-24 16:07:07", "confidence": "70"}')
# -------------------------------------------
# Time: 2019-05-24 16:07:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:11", "longitude": "149.331", "sender_id": "1", "latitude": "-37.58", "max_wind_speed": "12", "windspeed_knots": "6", "relative_humidity": "59", "precipitation": "0.00I", "geohash": "r364n", "air_temperature_celcius": "23"}')
# (None, '{"created_time": "2019-05-24 16:07:16", "longitude": "148.153", "sender_id": "1", "latitude": "-37.465", "max_wind_speed": "21", "windspeed_knots": "13.1", "relative_humidity": "43.5", "precipitation": "0.24G", "geohash": "r336g", "air_temperature_celcius": "11"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:07:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:21", "longitude": "144.39", "sender_id": "1", "latitude": "-37.288", "max_wind_speed": "13", "windspeed_knots": "6.1", "relative_humidity": "49.9", "precipitation": "0.02G", "geohash": "r1qev", "air_temperature_celcius": "12"}')
# (None, '{"geohash": "r1scs", "longitude": "141.8783", "sender_id": "2", "latitude": "-36.2618", "surface_temperature_celcius": "65", "created_time": "2019-05-24 16:07:22", "confidence": "89"}')
# (None, '{"created_time": "2019-05-24 16:07:26", "longitude": "146.6668", "sender_id": "1", "latitude": "-36.575", "max_wind_speed": "15.9", "windspeed_knots": "7.9", "relative_humidity": "53.6", "precipitation": "0.00G", "geohash": "r32rc", "air_temperature_celcius": "18"}')
# (None, '{"latitude": "-36.9326", "longitude": "142.054", "geohash": "r1mjb", "created_time": "2019-05-24 16:07:27", "confidence": "74", "sender_id": "3", "surface_temperature_celcius": "47"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:07:40
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:31", "longitude": "148.118", "sender_id": "1", "latitude": "-37.453", "max_wind_speed": "5.1", "windspeed_knots": "1.8", "relative_humidity": "39", "precipitation": "0.01G", "geohash": "r336f", "air_temperature_celcius": "6"}')
# (None, '{"created_time": "2019-05-24 16:07:36", "longitude": "142.5679", "sender_id": "1", "latitude": "-35.2881", "max_wind_speed": "22.9", "windspeed_knots": "16.8", "relative_humidity": "38.7", "precipitation": "0.00I", "geohash": "r1trh", "air_temperature_celcius": "17"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:07:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:41", "longitude": "143.2419", "sender_id": "1", "latitude": "-37.4661", "max_wind_speed": "15", "windspeed_knots": "9.1", "relative_humidity": "48.2", "precipitation": "0.00G", "geohash": "r1mfg", "air_temperature_celcius": "14"}')
# (None, '{"created_time": "2019-05-24 16:07:46", "longitude": "144.3142", "sender_id": "1", "latitude": "-36.4325", "max_wind_speed": "15", "windspeed_knots": "9.3", "relative_humidity": "61", "precipitation": "0.20G", "geohash": "r1w8e", "air_temperature_celcius": "26"}')
# (None, '{"geohash": "r1q85", "longitude": "144.3115", "sender_id": "2", "latitude": "-37.9378", "surface_temperature_celcius": "62", "created_time": "2019-05-24 16:07:48", "confidence": "87"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:07:51", "longitude": "143.428", "sender_id": "1", "latitude": "-37.858", "max_wind_speed": "14", "windspeed_knots": "7.9", "relative_humidity": "50.4", "precipitation": "0.00I", "geohash": "r1mbx", "air_temperature_celcius": "13"}')
# (None, '{"latitude": "-36.7228", "longitude": "142.3699", "geohash": "r1mpp", "created_time": "2019-05-24 16:07:55", "confidence": "84", "sender_id": "3", "surface_temperature_celcius": "58"}')
# (None, '{"created_time": "2019-05-24 16:07:56", "longitude": "141.2419", "sender_id": "1", "latitude": "-35.0889", "max_wind_speed": "14", "windspeed_knots": "7.8", "relative_humidity": "44.4", "precipitation": "0.00G", "geohash": "r1u2q", "air_temperature_celcius": "12"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:10
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:01", "longitude": "148.101", "sender_id": "1", "latitude": "-37.444", "max_wind_speed": "12", "windspeed_knots": "4.6", "relative_humidity": "42", "precipitation": "0.00I", "geohash": "r336f", "air_temperature_celcius": "9"}')
# (None, '{"created_time": "2019-05-24 16:08:06", "longitude": "143.4924", "sender_id": "1", "latitude": "-37.4437", "max_wind_speed": "13", "windspeed_knots": "6.1", "relative_humidity": "50.7", "precipitation": "0.00I", "geohash": "r1q4c", "air_temperature_celcius": "13"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:20
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:11", "longitude": "148.092", "sender_id": "1", "latitude": "-37.459", "max_wind_speed": "15.9", "windspeed_knots": "7.1", "relative_humidity": "48.5", "precipitation": "0.00G", "geohash": "r336c", "air_temperature_celcius": "13"}')
# (None, '{"geohash": "r1w46", "longitude": "143.5438", "sender_id": "2", "latitude": "-36.1462", "surface_temperature_celcius": "51", "created_time": "2019-05-24 16:08:12", "confidence": "74"}')
# (None, '{"created_time": "2019-05-24 16:08:16", "longitude": "146.154", "sender_id": "1", "latitude": "-36.275", "max_wind_speed": "14", "windspeed_knots": "7.9", "relative_humidity": "53.3", "precipitation": "0.00I", "geohash": "r1xct", "air_temperature_celcius": "18"}')
# (None, '{"latitude": "-36.4147", "longitude": "141.0669", "geohash": "r1s2f", "created_time": "2019-05-24 16:08:17", "confidence": "56", "sender_id": "3", "surface_temperature_celcius": "39"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:30
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:21", "longitude": "141.3146", "sender_id": "1", "latitude": "-36.3823", "max_wind_speed": "13", "windspeed_knots": "9.5", "relative_humidity": "43.7", "precipitation": "0.08G", "geohash": "r1s3p", "air_temperature_celcius": "10"}')
# (None, '{"geohash": "r1mdv", "longitude": "142.9811", "sender_id": "2", "latitude": "-37.4439", "surface_temperature_celcius": "46", "created_time": "2019-05-24 16:08:24", "confidence": "71"}')
# (None, '{"created_time": "2019-05-24 16:08:26", "longitude": "148.091", "sender_id": "1", "latitude": "-37.332", "max_wind_speed": "14", "windspeed_knots": "7.7", "relative_humidity": "39.3", "precipitation": "0.00G", "geohash": "r3379", "air_temperature_celcius": "8"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:40
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:31", "longitude": "148.091", "sender_id": "1", "latitude": "-37.434", "max_wind_speed": "15", "windspeed_knots": "8.6", "relative_humidity": "40", "precipitation": "0.00G", "geohash": "r3371", "air_temperature_celcius": "9"}')
# (None, '{"created_time": "2019-05-24 16:08:36", "longitude": "149.29", "sender_id": "1", "latitude": "-37.598", "max_wind_speed": "13", "windspeed_knots": "8.8", "relative_humidity": "53.5", "precipitation": "0.00I", "geohash": "r364j", "air_temperature_celcius": "18"}')
# (None, '{"latitude": "-36.663", "longitude": "141.3038", "geohash": "r1krr", "created_time": "2019-05-24 16:08:36", "confidence": "93", "sender_id": "3", "surface_temperature_celcius": "72"}')
#
# -------------------------------------------
# Time: 2019-05-24 16:08:50
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:41", "longitude": "142.2536", "sender_id": "1", "latitude": "-36.7179", "max_wind_speed": "15", "windspeed_knots": "9.2", "relative_humidity": "40.4", "precipitation": "0.04G", "geohash": "r1mpj", "air_temperature_celcius": "11"}')
# (None, '{"created_time": "2019-05-24 16:08:46", "longitude": "142.9892", "sender_id": "1", "latitude": "-37.6767", "max_wind_speed": "14", "windspeed_knots": "6.7", "relative_humidity": "53.8", "precipitation": "0.00I", "geohash": "r1m9t", "air_temperature_celcius": "18"}')
# (None, '{"geohash": "r1w48", "longitude": "143.4782", "sender_id": "2", "latitude": "-36.0888", "surface_temperature_celcius": "56", "created_time": "2019-05-24 16:08:46", "confidence": "83"}')
# (None, '{"latitude": "-36.4312", "longitude": "141.2064", "geohash": "r1s2t", "created_time": "2019-05-24 16:08:46", "confidence": "95", "sender_id": "3", "surface_temperature_celcius": "76"}')
# -------------------------------------------
# Time: 2019-05-24 16:09:00
# -------------------------------------------
# (None, '{"created_time": "2019-05-24 16:08:51", "longitude": "148.111", "sender_id": "1", "latitude": "-37.453", "max_wind_speed": "16.9", "windspeed_knots": "10.6", "relative_humidity": "45.3", "precipitation": "0.08G", "geohash": "r336f", "air_temperature_celcius": "11"}')
# (None, '{"created_time": "2019-05-24 16:08:56", "longitude": "143.428", "sender_id": "1", "latitude": "-37.858", "max_wind_speed": "12", "windspeed_knots": "6", "relative_humidity": "49.5", "precipitation": "0.00G", "geohash": "r1mbx", "air_temperature_celcius": "14"}')
# (None, '{"geohash": "r1tcj", "longitude": "143.3479", "sender_id": "2", "latitude": "-36.343", "surface_temperature_celcius": "40", "created_time": "2019-05-24 16:08:59", "confidence": "50"}')

# %%
#### Below code is used to test logics, no streaming 


### data for testing purpose
test = [(None, '{"created_time": "2019-05-24 16:05:01", "longitude": "145.2096", "sender_id": "1", "latitude": "-36.1462", "max_wind_speed": "14", "windspeed_knots": "9.7", "relative_humidity": "43.6", "precipitation": "0.20G", "geohash": "r1x62", "air_temperature_celcius": "10"}'),
(None, '{"created_time": "2019-05-24 16:05:06", "longitude": "143.841", "sender_id": "1", "latitude": "-38.167", "max_wind_speed": "11.1", "windspeed_knots": "5.3", "relative_humidity": "58.1", "precipitation": "0.00G", "geohash": "r1qkb", "air_temperature_celcius": "21"}'),
(None, '{"geohash": "r1qkb", "longitude": "143.8311","sender_id": "2", "latitude": "-37.0927", "surface_temperature_celcius": "53", "created_time": "2019-05-24 16:05:07", "confidence": "80"}')]

### same function as above
def sendDataToDB(messages): 
    
    client = MongoClient()
    db = client.fit5148_db
    week11 = db.new # send to this collection
    
    
    all_record = [] # to store the streaming records
    all_producer = {} # to store records from 3 producers
    all_location = {} # to store records from different locations
    
    # for each record in Dstream RDD partition, do the following
    for record in messages:
        data = json.loads(record[1]) # change data to json format 
        all_record.append(data) # add data to a list 
    
    # this part creates a dictionary that is in the form of {producer: [{record}]}
    # have 1 to 3 keys 
    # for each json item in the list, do the following 
    for m in all_record:
        if int(m['sender_id']) not in list(all_producer.keys()):
            all_producer[int(m['sender_id'])] = [m]
        else:
            all_producer[int(m['sender_id'])].append(m) 

            
    # this part joins the streams by geohash. use a dictionary to collect the results in the form of {geogash: [{record}]}
    # have 1 to 4 keys  
    # for each json item in the list, do the following 
    for m in all_record:
        if m['geohash'] not in list(all_location.keys()):
            all_location[m['geohash']] = [m]
        else: 
            all_location[m['geohash']].append(m)
     # when we only receive data from producer 1, send this climate data directly to MongoDB
    if len(set(list(all_producer.keys()))) == 1 and set(list(all_producer.keys())) == set([1]):
        
        for value in all_producer.values():
            
            content_climate = {'latitude':float(value[0]['latitude']), 
                               'longitude':float(value[0]['longitude']), 
                               'air_temperature_celcius':int(value[0]['air_temperature_celcius']), 
                               'relative_humidity':float(value[0]['relative_humidity']),
                               'windspeed_knots':float(value[0]['windspeed_knots']),
                               'max_wind_speed':float(value[0]['max_wind_speed']),
                               'precipitation':value[0]['precipitation'],
                               'datetime': value[0]['created_time']}

            week11.insert_one(content_climate)
   

    # when have records from more than 1 producers 
    elif len(set(all_producer.keys())) > 1:

        # loop through the locations dictionary to check scenearios:
        # 1. if we have only climate data (1 or 2 for the same location)--> insert into MongoDB
        # 2. if we have hotspot data and climate data --> embed hotspot in climate --> insert into MongoDB
        # 3. if we have hotspot data without climate data --> do not store
        # 4. if we have hotspot data with a shared location from TERRA and AQUA & also a matching climate record  
        #    --> average confidence and surface temperature celcius --> embed hotspot in climate --> insert into MongoDB
    
        for value in all_location.values():
            
            # scenario 1: location only has data from producer 1 
            if len(value) == 1 and int(value[0]['sender_id']) == 1:
                
                        content_climate = {'latitude':float(value[0]['latitude']), 
                               'longitude':float(value[0]['longitude']), 
                               'air_temperature_celcius':int(value[0]['air_temperature_celcius']), 
                               'relative_humidity':float(value[0]['relative_humidity']),
                               'windspeed_knots':float(value[0]['windspeed_knots']),
                               'max_wind_speed':float(value[0]['max_wind_speed']),
                               'precipitation':value[0]['precipitation'],
                               'datetime': value[0]['created_time']}
                        
                        week11.insert_one(content_climate)
    
          


            # scenario 2: same location has data from 
            # producer 1,1 || producer 1,2 || producer 1,3 || producer 2,3 (we do not store)
            elif len(value) == 2:

                # records could be in the order of 3,1 or 2,1
                # therefore loop through all the records then determine if we need to embed hotspot into climate
                
                has_climate = False # track if we have climate data 
                has_hotspot = False # track if we have hotspot data 
                has_another_climate = False # track if we have another climate data 


                # for each record in this location, do the following
                for i in range(len(value)):
                    
                    temp = value[i] # a dictionary 
                    
                    # the case which we have only seen one climate data, create a climate content
                    if int(temp['sender_id']) == 1 and has_climate == False:
                        content_climate = {'latitude':float(temp['latitude']), 
                               'longitude':float(temp['longitude']), 
                               'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                               'relative_humidity':float(temp['relative_humidity']),
                               'windspeed_knots':float(temp['windspeed_knots']),
                               'max_wind_speed':float(temp['max_wind_speed']),
                               'precipitation':temp['precipitation'],
                               'datetime': temp['created_time'],
                               'hotspot':[]}


                        has_climate = True # flag that this location has a climate data 

                    # the case which we have two climate data, create a second climate content
                    elif int(temp['sender_id']) == 1 and has_climate == True:

                        content_climate_2 = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time']}

                        has_another_climate = True

                    # create a hotspot content
                    else:

                        content_hotspot = {'latitude':float(temp['latitude']), 
                                                'longitude':float(temp['longitude']), 
                                                'confidence':int(temp['confidence']), 
                                                'time':temp['created_time'].split(' ')[1],
                                                'surface_temperature_celcius':float(temp['surface_temperature_celcius'])
                                               }



                        has_hotspot = True # flag that this location has a hotspot data 


                # perform embedding and insertion into MongoDB when we have both climate data & hotspot data 
                if has_hotspot and has_climate: 
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate
                    
                    try:
                        week11.insert_one(content_climate)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))
                
                # when we have 2 climate records 
                elif has_another_climate == True:
                    
                    content_climate.pop('hotspot') # do not need the extra hotspot attribute 
               
                    try:
                        week11.insert_one(content_climate)
                        week11.insert_one(content_climate_2)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))



         

            # when we have data from more than 1 producer
            # could have 1,1,2 || 1,1,3 || 1,2,3 || 1,1,2,3 
            # last two cases need to average confidence and air_temperature_celcius for both hotspots
            if len(value) > 2: 
                
                has_climate = False
                has_hotspot = False
                has_another_climate = False
        

                # for each record in this location, do the following
                for i in range(len(value)):
                    
                    temp = value[i] # a dictionary 

                    # the case which we have only seen one climate data, create a climate content
                    if int(temp['sender_id']) == 1 and has_climate == False:

                        content_climate = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time'],
                                   'hotspot':[]}


                        has_climate = True

                    # the case which we have two climate data, create a second climate content
                    elif int(temp['sender_id']) == 1 and has_climate == True:

                        content_climate_2 = {'latitude':float(temp['latitude']), 
                                   'longitude':float(temp['longitude']), 
                                   'air_temperature_celcius':int(temp['air_temperature_celcius']), 
                                   'relative_humidity':float(temp['relative_humidity']),
                                   'windspeed_knots':float(temp['windspeed_knots']),
                                   'max_wind_speed':float(temp['max_wind_speed']),
                                   'precipitation':temp['precipitation'],
                                   'datetime': temp['created_time'],
                                   'hotspot':[]}

                        has_another_climate = True

                    
                    # the case which we have hotspot data, create hotspot content for potential embedding
                    else:


                        # when there's hotspot exists for the same location from a different producer 
                        if has_hotspot: 

                            content_hotspot['confidence'] = (content_hotspot['confidence'] + float(temp['confidence'])) / 2
                            content_hotspot['surface_temperature_celcius'] = (content_hotspot['surface_temperature_celcius'] \
                                                                              + float(temp['surface_temperature_celcius'])) / 2


                        # when there's no hotspot exists from either 2 or 3 
                        else: 
                            content_hotspot = {'latitude':float(temp['latitude']), 
                                                'longitude':float(temp['longitude']), 
                                                'confidence':int(temp['confidence']), 
                                                'time':temp['created_time'].split(' ')[1],
                                                'surface_temperature_celcius':float(temp['surface_temperature_celcius'])
                                               }



                        has_hotspot = True 


                # insert two records when we have 1,1,2 or 1,1,3 or 1,1,2,3
                if has_another_climate == True:
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate record 1
                    content_climate_2['hotspot'].append(content_hotspot) # embed hotspot into climate record 2
                    try:
                        week11.insert_one(content_climate)
                        week11.insert_one(content_climate_2)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))

                # insert one record when we have 1,2,3
                else:
                    content_climate['hotspot'].append(content_hotspot) # embed hotspot into climate
                    try:
                        week11.insert_one(content_climate)
                        print ('success')
                    except Exception as ex:
                        print("Exception Occured. Message: {0}".format(str(ex)))


                
        client.close()

        
        
# apply the function on test data
sendDataToDB(test)
# Out:
# success

# %%
#### results of running sendDataToDB(test)



# { "_id" : ObjectId("5ce78b219343692aec31d045"), 
#      "hotspot" : [ { "surface_temperature_celcius" : 53, 
#                     "longitude" : 143.8311, 
#                     "confidence" : 80, 
#                     "latitude" : -37.0927,
#                     "time": "16:05:07"} ], 
#      "max_wind_speed" : 11.1, 
#      "air_temperature_celcius" : 21, 
#      "windspeed_knots" : 5.3, 
#      "datetime" : "2019-05-24 16:05:06", 
#      "longitude" : 143.841, 
#      "relative_humidity" : 58.1, "precipitation" : 
#      "0.00G", "latitude" : -38.167 }

# { "_id" : ObjectId("5ce78b219343692aec31d046"), 
#  "max_wind_speed" : 14, 
#  "air_temperature_celcius" : 10, 
#  "windspeed_knots" : 9.7, 
#  "datetime" : "2019-05-24 16:05:01", 
#  "longitude" : 145.2096, 
#  "relative_humidity" : 43.6, 
#  "precipitation" : "0.20G",
#  "latitude" : -36.1462 }

# %%
# from pprint import pprint 
# client = MongoClient()
# db = client.fit5148_db
# week11 = db.new

# for record in week11.find():
#     pprint (record)
#     break
